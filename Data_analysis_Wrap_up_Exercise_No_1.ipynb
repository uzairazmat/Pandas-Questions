# %% [markdown]
# <a href="https://colab.research.google.com/github/uzairazmat/Pandas-Questions/blob/main/Data_analysis_Wrap_up_Exercise_No_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Import pandas as pd

# %%
import pandas as pd  #import pandas as pd

# %% [markdown]
# create any dictionary that have 3 key pairs that containing a list and than convert into data frame

# %%
dict1 = {

        "name":["ahmad" , "mohsin" ,"husian " , "amna", "sana ", "ayesha"  ]  ,
        "marks" : [400,600, 300 , 900 , 788, 666],
        "gender": ["Male","Male","Male","Female", "Female", "Female"  ]

        }  #create dictionary

# %%
data = pd.DataFrame(dict1)

# %% [markdown]
# ## 2. Display top 3 rows of data set

# %%
data.head(3)
# Out:
#       name  marks gender
# 0    ahmad    400   Male
# 1   mohsin    600   Male
# 2  husian     300   Male

# %% [markdown]
# ## 3. Check last 5 Rows of data set

# %%
data.tail()
# Out:
#       name  marks  gender
# 1   mohsin    600    Male
# 2  husian     300    Male
# 3     amna    900  Female
# 4    sana     788  Female
# 5   ayesha    666  Female

# %% [markdown]
# ## 4. Find shape of our data set (number of rows and col)

# %%
row , col=  data.shape
print(row, col)
# Out:
# 6 3

# %% [markdown]
# ## 5. print everything about your data col , rows , their data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   marks   6 non-null      int64
#  2   gender  6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %% [markdown]
# # 6. check Null values in Data set

# %%
data.isnull().sum()
# Out:
# name      0
# marks     0
# gender    0
# dtype: int64

# %% [markdown]
# ## 8. Get Overall Statistics About the Data fram

# %%
data.describe()
# Out:
#            marks
# count    6.00000
# mean   609.00000
# std    227.69014
# min    300.00000
# 25%    450.00000
# 50%    633.00000
# 75%    757.50000
# max    900.00000

# %%
data.describe(include = "all")
# Out:
#          name      marks gender
# count       6    6.00000      6
# unique      6        NaN      2
# top     ahmad        NaN   Male
# freq        1        NaN      3
# mean      NaN  609.00000    NaN
# std       NaN  227.69014    NaN
# min       NaN  300.00000    NaN
# 25%       NaN  450.00000    NaN
# 50%       NaN  633.00000    NaN
# 75%       NaN  757.50000    NaN
# max       NaN  900.00000    NaN

# %% [markdown]
# ## 8. Find unique values from the Gender col , uinique values for the particular coloumn

# %%
data["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ##9. Display number of unique values in a particular col

# %%
len(data["gender"].unique())
# Out:
# 2

# %% [markdown]
# ## 10. Display count of unique values in Gender col

# %%
data["gender"].value_counts()
# Out:
# gender
# Male      3
# Female    3
# Name: count, dtype: int64

# %% [markdown]
# ## 11. Display the row that having marks > 400 and < 750
#
# ANd the len

# %%
print(data[(data["marks"] >= 400) & (data["marks"] < 800)])
print()
# Out:
#      name  marks  gender
# 0   ahmad    400    Male
# 1  mohsin    600    Male
# 4   sana     788  Female
# 5  ayesha    666  Female

# %%
len(data[(data["marks"] >= 400) & (data["marks"] < 800)])
# Out:
# 4

# %%
sum(data["marks"].between(400 , 800))
# Out:
# 4
